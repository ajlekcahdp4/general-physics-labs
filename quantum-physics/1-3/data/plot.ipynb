# %%
import csv
import numpy as np
import matplotlib.pyplot as plt
import scipy as sp

# %%
I, V = [], []
with open("./2.53.csv", 'r') as file:
  csvreader = csv.DictReader(file, delimiter=',')
  for row in csvreader:
    print(row)
    I.append(float(row['I']))
    V.append(float(row['V']))
# Out:
# {'V': '0.51300000000000001', 'I': '0.062300000000000001'}
# {'V': '1', 'I': '0.65100000000000002'}
# {'V': '1.1499999999999999', 'I': '0.99399999999999999'}
# {'V': '1.25', 'I': '1.167'}
# {'V': '1.5', 'I': '1.446'}
# {'V': '1.6000000000000001', 'I': '1.5700000000000001'}
# {'V': '1.75', 'I': '1.615'}
# {'V': '1.8', 'I': '1.613'}
# {'V': '2', 'I': '1.498'}
# {'V': '2.5', 'I': '1.1970000000000001'}
# {'V': '3', 'I': '0.92300000000000004'}
# {'V': '3.5', 'I': '0.76200000000000001'}
# {'V': '3.9900000000000002', 'I': '0.66500000000000004'}
# {'V': '4.5', 'I': '0.5907'}
# {'V': '5', 'I': '0.55000000000000004'}
# {'V': '5.5099999999999998', 'I': '0.52300000000000002'}
# {'V': '6', 'I': '0.52300000000000002'}
# {'V': '6.5', 'I': '0.54100000000000004'}
# {'V': '7', 'I': '0.55100000000000005'}
# {'V': '7.5', 'I': '0.56699999999999995'}
# {'V': '8', 'I': '0.58599999999999997'}
# {'V': '8.5', 'I': '0.64100000000000001'}
# {'V': '9', 'I': '0.70599999999999996'}
# {'V': '9.5099999999999998', 'I': '0.81399999999999995'}
# {'V': '10', 'I': '0.89239999999999997'}
# {'V': '10.5', 'I': '0.96299999999999997'}
# {'V': '11', 'I': '1.0900000000000001'}
# {'V': '11.5', 'I': '1.3220000000000001'}
# {'V': '11.9', 'I': '1.4319999999999999'}

# %%
plt.figure(figsize=[16,9])
plt.scatter(V, I, color="red")
plt.plot(V, I)
